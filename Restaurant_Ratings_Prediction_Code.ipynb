# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthshh19/Restaurant-Ratings-Prediction/blob/main/Restaurant_Ratings_Prediction_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Restaurant Ratings Prediction**
#
# Objective: To identify the variables influencing restaurant ratings using data from FoodieBay

# %% [markdown]
# ## **Importing Libraries**

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for model evaluation
from sklearn.metrics import precision_recall_curve, precision_recall_curve, classification_report
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## **Loading and Inspecting Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# loading dataset
FoodieBay = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MLA2/FoodieBay.csv")

#exploring the dataset
print(FoodieBay)
print('Sample size:', FoodieBay.shape[0])
print('Number of columns:', FoodieBay.shape[1])
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/d2v-cafe-1-ba...
# 1      https://www.zomato.com/bangalore/the-burger-pl...
# 2      https://www.zomato.com/bangalore/millet-mama-b...
# 3      https://www.zomato.com/bangalore/red-onion-sha...
# 4      https://www.zomato.com/bangalore/chaiywaala-da...
# ...                                                  ...
# 40125  https://www.zomato.com/bangalore/yumlane-brook...
# 40126  https://www.zomato.com/bangalore/american-dess...
# 40127  https://www.zomato.com/bangalore/new-arya-bhav...
# 40128  https://www.zomato.com/bangalore/le-charcoal-x...
# 40129  https://www.zomato.com/bangalore/kaati-zone-ch...
#
#                                                  address                 name  \
# 0      173/218, GF, Opposite Ranka Colony, Bannerghat...             D2V Cafe
# 1      2nd Floor, MMR Plaza, Above DCB Bank, Sarjapur...     The Burger Place
# 2      Next To Surana College, South End Circle, Basa...          Millet Mama
# 3      Money Chambers Double Road, Shanti Nagar, Bang...            Red Onion
# 4      Shop 67, 69, 70, Inside Ramaiah Campus, New BE...  Chaiywaala Da Dhaba
# ...                                                  ...                  ...
# 40125  ACES Layout Road, Kundanahalli Gate, Brookefie...              Yumlane
# 40126  18, 2nd H Cross, Dodda Banaswadi Main Road, Ne...    American Desserts
# 40127                            113, MG Road, Bangalore      New Arya Bhavan
# 40128  2334, Aarush Arcade, 17th Cross, 1st Sector, H...   Le Charcoal Xpress
# 40129       48, Triumph Towers, Church Street, Bangalore           Kaati Zone
#
#                                       phone               location  \
# 0          +91 9886986111\r\n+91 8550051111      Bannerghatta Road
# 1                            +91 9108974600  Koramangala 1st Block
# 2          +91 7411918648\r\n+91 9986975625           Basavanagudi
# 3                            +91 8867253669           Shanti Nagar
# 4            +91 8217431260\n+91 7975991975           New BEL Road
# ...                                     ...                    ...
# 40125                                   NaN            Brookefield
# 40126                        +91 9686415784              Banaswadi
# 40127                          080 40913062                MG Road
# 40128      +91 9036300066\r\n+91 9036300088                    HSR
# 40129  +91 9148398566\r\r\r\r\n080 65660000          Church Street
#
#                 rest_type                               cuisines  \
# 0                    Cafe                                   Cafe
# 1             Quick Bites         Burger, Continental, Fast Food
# 2             Quick Bites             South Indian, Healthy Food
# 3           Casual Dining  Chinese, North Indian, Biryani, Kebab
# 4                    Cafe                              Cafe, Tea
# ...                   ...                                    ...
# 40125  Takeaway, Delivery                       Pizza, Fast Food
# 40126  Takeaway, Delivery                       Desserts, Bakery
# 40127         Quick Bites   Street Food, Beverages, North Indian
# 40128         Quick Bites           Arabian, BBQ, Rolls, Chinese
# 40129         Quick Bites              Fast Food, Biryani, Rolls
#
#                                                menu_item listed_in_type  \
# 0                                                     []          Cafes
# 1                                                     []       Dine-out
# 2                                                     []       Delivery
# 3      ['Hyderabadi Biryani', 'Special Veg Combo', 'S...       Delivery
# 4                                                     []       Dine-out
# ...                                                  ...            ...
# 40125                                                 []       Delivery
# 40126                                                 []       Delivery
# 40127                                                 []       Delivery
# 40128                                                 []       Delivery
# 40129  ['Chilli Paneer Roll', 'Paneer Tikka Roll', 'C...       Delivery
#
#               listed_in_city online_order book_table  ave_cost_for_two  \
# 0                   JP Nagar           No         No               700
# 1      Koramangala 5th Block          Yes         No               400
# 2                  Jayanagar          Yes         No               200
# 3               Brigade Road          Yes        Yes              1200
# 4               New BEL Road          Yes         No               250
# ...                      ...          ...        ...               ...
# 40125             Whitefield           No         No               NaN
# 40126           Kammanahalli          Yes         No               500
# 40127                MG Road           No         No               300
# 40128              Bellandur          Yes         No               500
# 40129           Brigade Road          Yes         No               350
#
#                                               dish_liked  votes  \
# 0                                                    NaN     13
# 1                                                    NaN     28
# 2                                                    NaN     18
# 3      Fish, Dumplings, Biryani, Paneer Tikka Masala,...    550
# 4      Ginger Chai, Pakoda, Tea, Paneer Thali, Chole ...     67
# ...                                                  ...    ...
# 40125                                                NaN     25
# 40126                                                NaN     23
# 40127                                                NaN     23
# 40128  Pita Bread, Rolls, Shawarma Roll, Lebanese Sha...    162
# 40129             Rolls, Chicken Tikka Roll, Cheese Roll    163
#
#        ave_review_ranking  rate
# 0                       5     4
# 1                       4     4
# 2                       4     4
# 3                       5     4
# 4                       3     4
# ...                   ...   ...
# 40125                   2     3
# 40126                   3     4
# 40127                   3     3
# 40128                   4     4
# 40129                   3     3
#
# [40130 rows x 17 columns]
# Sample size: 40130
# Number of columns: 17

# %%
print(FoodieBay.info())
print(FoodieBay.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40130 entries, 0 to 40129
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   url                 40130 non-null  object
#  1   address             40130 non-null  object
#  2   name                40130 non-null  object
#  3   phone               39246 non-null  object
#  4   location            40130 non-null  object
#  5   rest_type           40130 non-null  object
#  6   cuisines            40112 non-null  object
#  7   menu_item           40130 non-null  object
#  8   listed_in_type      40130 non-null  object
#  9   listed_in_city      40130 non-null  object
#  10  online_order        40130 non-null  object
#  11  book_table          40130 non-null  object
#  12  ave_cost_for_two    39890 non-null  float64
#  13  dish_liked          17351 non-null  object
#  14  votes               40130 non-null  int64
#  15  ave_review_ranking  33751 non-null  float64
#  16  rate                31794 non-null  float64
# dtypes: float64(3), int64(1), object(13)
# memory usage: 5.2+ MB
# None
# (40130, 17)

# %% [markdown]
# ##**Converting Categorical variables to Numerical variables**

# %%
#convert categorical data to numerical
def coding_intersection(x):
    if x=='Yes': return 1
    if x=='No': return 0

FoodieBay['online_order'] = FoodieBay['online_order'].apply(coding_intersection)
FoodieBay['book_table'] = FoodieBay['book_table'].apply(coding_intersection)

# %%
def coding_rest_type(x):
    if x=='Bakery': return 1
    if x=='Cafe': return 2
    if x=='Casual Dining': return 3
    if x=='Casual Dining, Bar': return 4
    if x=='Delivery': return 5
    if x=='Quick Bites': return 6
    if x=='Takeaway, Delivery': return 7

FoodieBay['rest_type'] = FoodieBay['rest_type'].apply(coding_rest_type)

# %%
def coding_listed_in_type(x):
    if x=='Buffet': return 1
    if x=='Cafes': return 2
    if x=='Delivery': return 3
    if x=='Dine-out': return 4
    if x=='Desserts': return 5
    if x=='Pubs and bars': return 6
    if x=='Drinks & nightlife': return 7

FoodieBay['listed_in_type'] = FoodieBay['listed_in_type'].apply(coding_listed_in_type)

# %%
print(FoodieBay.sample(10))
# Out:
#                                                      url  \
# 11374  https://www.zomato.com/bangalore/just-bake-mag...
# 24882  https://www.zomato.com/bangalore/shilpa-vegeta...
# 30033  https://www.zomato.com/bangalore/prawn-crunch-...
# 37361  https://www.zomato.com/bangalore/sri-sai-laksh...
# 26916  https://www.zomato.com/bangalore/uno-chicago-b...
# 5095   https://www.zomato.com/bangalore/sang-grail-2-...
# 32208  https://www.zomato.com/bangalore/safa-hotel-sh...
# 13139  https://www.zomato.com/bangalore/owls-kitchen-...
# 28015  https://www.zomato.com/bangalore/utse-kitchen-...
# 11704  https://www.zomato.com/bangalore/shuchi-ruchi-...
#
#                                                  address  \
# 11374  80/1, 125 (1268), S S Arcade Shop, Near Apex B...
# 24882  26, Lady Curzon Road, Opposite Bowring Hospita...
# 30033  Number 7, 20th Main, BTM 1st Stage, Gangotri C...
# 37361  33/1, Sector 6, Aayee Matha Temple Rd, Vinayak...
# 26916  Shop FB-02, Upper Ground Floor, Prestige Shant...
# 5095   Near Big Bazaar, Kothnur Village Main Road, Na...
# 32208            17, DRK Street, Shivajinagar, Bangalore
# 13139  29th Main Road, EWS Colony, Stage 2 Bengaluru,...
# 28015     73, Kamaraj Road, Commercial Street, Bangalore
# 11704  92, 1st Main, 10th Cross Temple Road, Sampige ...
#
#                                name                               phone  \
# 11374                     Just Bake                      +91 8970010111
# 24882  Shilpa Vegetarian Restaurant      +91 9535049590\r\n080 25592625
# 30033                  Prawn Crunch                      +91 7899093022
# 37361               Sri Sai Lakshmi                      +91 9901081498
# 26916       Uno Chicago Bar & Grill    +91 9667540036\r\n+91 7042349751
# 5095                     Sang Grail                      +91 9341457777
# 32208                    Safa Hotel                      +91 9830199022
# 13139                 Owl's Kitchen      080 45133111\r\n+91 9900311141
# 28015                  Utse Kitchen  080 25566688\r\r\r\r\n080 48906688
# 11704                  Shuchi Ruchi      +91 9448804902\n+91 7996992068
#
#                 location  rest_type                             cuisines  \
# 11374        Magadi Road          1                               Bakery
# 24882       Shivajinagar          6  South Indian, North Indian, Chinese
# 30033                BTM          6                   Fast Food, Seafood
# 37361                HSR          5                         South Indian
# 26916         Whitefield          4                             American
# 5095            JP Nagar          6                         Healthy Food
# 32208       Shivajinagar          6                North Indian, Biryani
# 13139                BTM          5                North Indian, Chinese
# 28015  Commercial Street          3             Nepalese, Tibetan, Momos
# 11704       Malleshwaram          6   Chinese, North Indian, Street Food
#
#                                                menu_item  listed_in_type  \
# 11374                                                 []               3
# 24882                                                 []               3
# 30033  ['Fish Fingers [5 Pieces]', 'Lobster Bite [10 ...               3
# 37361                                                 []               3
# 26916                                                 []               4
# 5095                                                  []               3
# 32208                                                 []               4
# 13139                                                 []               3
# 28015  ['Veg Tibetan Set Meal', 'Chicken Tibetan Set ...               3
# 11704  ['Gobi Manchurian', 'Paneer Manchurian', 'Pane...               3
#
#               listed_in_city  online_order  book_table  ave_cost_for_two  \
# 11374           Malleshwaram             1           0               400
# 24882           Brigade Road             0           0               350
# 30033  Koramangala 4th Block             1           0               400
# 37361                    HSR             0           0               200
# 26916            Brookefield             0           1              1300
# 5095       Bannerghatta Road             0           0               300
# 32208          Church Street             0           0               200
# 13139      Bannerghatta Road             0           0               500
# 28015           Brigade Road             1           0               800
# 11704           Malleshwaram             1           0               350
#
#                                               dish_liked  votes  \
# 11374                                                NaN     16
# 24882                                                NaN      0
# 30033                                                NaN      8
# 37361                                                NaN      0
# 26916  Deep Dish Pizza, Mocktails, Onion Rings, Thin ...    103
# 5095                                                 NaN     34
# 32208                                                NaN      0
# 13139                                            Brownie     44
# 28015  Momos, Thukpa, Noodles, Nepali Thali, Chicken ...    172
# 11704  Aloo Palya, Masala Poori, Panipuri, Rolls, Cha...    340
#
#        ave_review_ranking  rate
# 11374                   4     3
# 24882                 NaN   NaN
# 30033                   4     3
# 37361                 NaN   NaN
# 26916                   4     4
# 5095                    4     4
# 32208                   4   NaN
# 13139                   3     3
# 28015                   4     4
# 11704                   4     4

# %% [markdown]
# ## **Exploratory Data Analysis**
#
#
# Univariate analysis
#
# Bivariate analysis
#
# Multivariate analysis

# %% [markdown]
# ### Univariate Analysis

# %%
FoodieBay['ave_cost_for_two'].describe()
# Out:
# count   39890
# mean      507
# std       324
# min        40
# 25%       300
# 50%       400
# 75%       600
# max      2500
# Name: ave_cost_for_two, dtype: float64

# %%
FoodieBay['ave_review_ranking'].describe()
# Out:
# count   33751
# mean        4
# std         1
# min         1
# 25%         3
# 50%         4
# 75%         4
# max         5
# Name: ave_review_ranking, dtype: float64

# %%
FoodieBay['votes'].describe()
# Out:
# count   40130
# mean      226
# std       599
# min         0
# 25%         6
# 50%        36
# 75%       174
# max     12121
# Name: votes, dtype: float64

# %%
FoodieBay['rate'].describe()
# Out:
# count   31794
# mean        4
# std         0
# min         2
# 25%         3
# 50%         4
# 75%         4
# max         5
# Name: rate, dtype: float64

# %%
# Using the numerical variables from the dataset
numerical_variables = ['rate', 'ave_cost_for_two', 'ave_review_ranking']

# Printing the list of numerical variables
print("Numerical Variables:", numerical_variables)

# Displaying histograms using seaborn
for variable in numerical_variables:
    sns.histplot(data=FoodieBay, x=variable, bins= 10, kde= True, color='blue')
    plt.title(f"Histogram of {variable}")
    plt.show()
# Out:
# Numerical Variables: ['rate', 'ave_cost_for_two', 'ave_review_ranking']

# %%
# Using countplots to visualise the distribution of categorical variables
numerical_variables = ['listed_in_type', 'rest_type', 'online_order', 'book_table']

# Printing the list of numerical variables
print("Numerical Variables:", numerical_variables)

# Displaying histograms using seaborn
for variable in numerical_variables:
    plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
    ax = sns.countplot(data=FoodieBay, x=variable)
    plt.title(f"Countplot of {variable}")

    # Adding count labels on top of each bar
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                    textcoords='offset points')

    plt.show()
# Out:
# Numerical Variables: ['listed_in_type', 'rest_type', 'online_order', 'book_table']

# %%
sns.histplot(data=FoodieBay, x='votes', bins=40, kde=True,color='blue')
# Out:
# <Axes: xlabel='votes', ylabel='Count'>

# %% [markdown]
# ### Bivariate Analysis

# %%
num_variables=['listed_in_type', 'rest_type', 'online_order', 'book_table']
for i in num_variables:
    sns.boxplot(data= FoodieBay, x=i, y= 'rate')
    plt.show()

# %%
num_variables = ['ave_cost_for_two', 'ave_review_ranking', 'votes']

for i in num_variables:
    sns.scatterplot(data=FoodieBay, x=i, y='rate')

    # Add a trendline (regression line)
    sns.regplot(data=FoodieBay, x=i, y='rate', scatter=False, color='red')

    plt.title(f'Scatterplot with Trendline for {i} vs. Rate')
    plt.xlabel(i)
    plt.ylabel('Rate')

    plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=FoodieBay, x='rest_type', y='ave_cost_for_two', ci=None, palette='Set2')

# Add data labels (annotations)
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.xlabel('Restaurant Type')
plt.ylabel('Average Cost for Two (INR)')
plt.title('Average Cost for Two by Restaurant Type')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-176-3fbcf62a86ad>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=FoodieBay, x='rest_type', y='ave_cost_for_two', ci=None, palette='Set2')
# <ipython-input-176-3fbcf62a86ad>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=FoodieBay, x='rest_type', y='ave_cost_for_two', ci=None, palette='Set2')

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=FoodieBay, x='rest_type', y='rate', ci=None, palette='Set2')

# Adding data labels
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.xlabel('Restaurant Type')
plt.ylabel('rate')
plt.title('Rating by Restaurant Type')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-177-8ea64c1a3380>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=FoodieBay, x='rest_type', y='rate', ci=None, palette='Set2')
# <ipython-input-177-8ea64c1a3380>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=FoodieBay, x='rest_type', y='rate', ci=None, palette='Set2')

# %%
df = pd.DataFrame(FoodieBay)

# Sort the DataFrame by ratings in descending order to find the best-performing restaurants
best_performing = df.sort_values(by='rate', ascending=False)

worst_performing = df.sort_values(by='rate')

# Extract just the names of the best-performing and worst-performing restaurants
best_names = best_performing['name'].tolist()
worst_names = worst_performing['name'].tolist()

print("Best-Performing Restaurants:")
print(best_names)
print(worst_names)
# Out:
# Best-Performing Restaurants:
# ['Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Flechazo', 'Asia Kitchen By Mainland China', 'Punjab Grill', "AB's - Absolute Barbecues", "AB's - Absolute Barbecues", 'Flechazo', 'Asia Kitchen By Mainland China', "AB's - Absolute Barbecues", 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', "AB's - Absolute Barbecues", 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', "AB's - Absolute Barbecues", 'SantÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Spa Cuisine', 'Punjab Grill', "AB's - Absolute Barbecues", "AB's - Absolute Barbecues", 'Flechazo', 'Punjab Grill', 'Punjab Grill', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Asia Kitchen By Mainland China', 'Punjab Grill', "Chili's American Grill & Bar", "AB's - Absolute Barbecues", 'O.G. Variar & Sons', 'The Black Pearl', 'The Pizza Bakery', "Chili's American Grill & Bar", 'The Pizza Bakery', "Chili's American Grill & Bar", 'The Black Pearl', "AB's - Absolute Barbecues", "Chili's American Grill & Bar", "Chili's American Grill & Bar", 'The Pizza Bakery', 'The Globe Grub', 'The Globe Grub', 'Barbeque Nation', 'CTR', "AB's - Absolute Barbecues", 'The Pizza Bakery', 'CTR', 'The Pizza Bakery', "Brahmin's Coffee Bar", 'The Black Pearl', 'Barbecue by Punjab Grill', 'The Black Pearl', 'The Pizza Bakery', "Chili's American Grill & Bar", 'O.G. Variar & Sons', 'The Black Pearl', 'Punjab Grill', "AB's - Absolute Barbecues", "AB's - Absolute Barbecues", 'Punjab Grill', 'Chianti', 'Mainland China', "AB's - Absolute Barbecues", 'Flechazo', 'Burma Burma', 'You Mee', 'Chianti', 'Barbeque Nation', 'The Black Pearl', 'Mainland China', 'Barbeque Nation', 'Burma Burma', 'TBC Sky Lounge', 'The Black Pearl', 'The Black Pearl', 'TBC Sky Lounge', "AB's - Absolute Barbecues", 'Barbeque Nation', 'Barbeque Nation', 'Barbeque Nation', 'Mainland China', 'CTR', 'Barbeque Nation', 'The Black Pearl', 'Barbeque Nation', 'Mainland China', 'CTR', 'Barbeque Nation', 'Chianti', "AB's - Absolute Barbecues", 'Barbeque Nation', "AB's - Absolute Barbecues", "AB's - Absolute Barbecues", 'The Black Pearl', 'Chianti', 'Flechazo', 'Flechazo', 'You Mee', 'Barbeque Nation', 'Barbeque Nation', 'Maziga', 'The Big Barbeque', 'The Black Pearl', 'Chianti', 'The Black Pearl', 'Barbeque Nation', 'Mainland China', 'The Black Pearl', 'Barbeque Nation', 'Chianti', 'The Black Pearl', 'Taaza Thindi', 'Barbecue by Punjab Grill', 'You Mee', 'Barbeque Nation', 'The Black Pearl', 'The Big Barbeque', 'Maziga', 'Barbeque Nation', 'TBC Sky Lounge', 'Barbeque Nation', 'The Black Pearl', 'Mainland China', 'Barbeque Nation', 'Burma Burma', 'Barbeque Nation', 'Burma Burma', 'The Black Pearl', 'The Black Pearl', 'Oota Bangalore', 'Sea Lions BBQ & Grills', 'Toast & Tonic', 'Via Milano', 'Brik Oven', 'The Fatty Bao - Asian Gastro Bar', 'eat.fit', 'The Fatty Bao - Asian Gastro Bar', "Galito's", 'The Hole in the Wall Cafe', "Galito's", 'Smoke House Deli', 'Brik Oven', 'Brik Oven', 'The Fatty Bao - Asian Gastro Bar', 'Brik Oven', 'Mahjong Room - WelcomHotel Bengaluru', 'Smoke House Deli', 'Smoke House Deli', 'Hunger Camp', "Galito's", 'MISU', 'MISU', 'MISU', 'Oota Bangalore', 'The Fatty Bao - Asian Gastro Bar', 'The Blue Wagon - Kitchen', 'Roots', 'Smoke House Deli', 'Olive Bar And Kitchen', 'The Blue Wagon - Kitchen', 'eat.fit', "Chili's American Grill & Bar", 'Smoke House Deli', 'Brik Oven', 'Smoke House Deli', 'MISU', 'Sea Rock', 'The Blue Wagon - Kitchen', 'Chianti', 'The Hole in the Wall Cafe', 'Smoke House Deli', "Galito's", 'Stories', 'Toast & Tonic', 'The Hole in the Wall Cafe', 'Stories', " ...
# ['Alibi - Maya International Hotel', 'Alibi - Maya International Hotel', 'Alibi - Maya International Hotel', 'Alibi - Maya International Hotel', 'Alibi - Maya International Hotel', 'Bhagini', 'Bhagini', 'Mast Kalandar', 'Bageecha', "Decker's Lane", 'Bageecha', "Ammi's Biryani", "Decker's Lane", 'Midnight Hunger Solutions 24/7', "Ammi's Biryani", "Ammi's Biryani", "Ammi's Biryani", 'Mast Kalandar', 'Mast Kalandar', 'Midnight Hunger Solutions 24/7', 'Midnight Hunger Solutions 24/7', 'Mast Kalandar', 'Midnight Hunger Solutions 24/7', 'Midnight Hunger Solutions 24/7', 'Madurai Idly Shop', "Decker's Lane", 'Midnight Hunger Solutions 24/7', 'Midnight Hunger Solutions 24/7', "Decker's Lane", 'Midnight Hunger Solutions 24/7', 'Midnight Hunger Solutions 24/7', 'Mamma Mexicana', 'Tandoor Hut', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Mamma Mexicana', 'Tandoor Hut', 'Taste Of Kerala', 'Bageecha', 'Taste Of Kerala', 'Tandoor Hut', 'Mamma Mexicana', 'Pizza Hut', 'Mamma Mexicana', 'Tandoor Hut', 'Madurai Idly Shop', 'Tandoor Hut', 'Bageecha', 'Taste Of Kerala', 'Tandoor Hut', "Vasudev Adiga's", 'Bhagini', 'Meghana Biryani', 'Cafe Coffee Day', 'Biryani Junction', 'Biryani Junction', 'Biryani Junction', 'Mast Kalandar', 'Bhagini', "Woody's", 'Taste Of Kerala', 'Bhagini', 'Punjabi Tadka', 'Bhagini', 'Vande Matharam', 'Meghana Biryani', 'Vande Matharam', 'Mast Kalandar', "Woody's", 'Crunch Pizzas', 'Biryani Junction', 'Vande Matharam', "Vasudev Adiga's", 'Mast Kalandar', 'Bhagini', "Woody's", 'Meghana Biryani', "Vasudev Adiga's", 'Mast Kalandar', 'Mast Kalandar', 'Bhagini', 'Mast Kalandar', "Vasudev Adiga's", "Woody's", 'Bhagini', "Woody's", 'Biryani Junction', "Woody's", 'Meghana Biryani', 'Cafe Coffee Day', 'Vande Matharam', 'Biryani Junction', 'Biryani Junction', 'Meghana Biryani', 'Punjabi Tadka', 'Taste Of Kerala', 'Biryani Junction', 'Mast Kalandar', 'Crunch Pizzas', 'Biryani Junction', 'Bhagini', 'Subway', 'Punjabi Daawat', 'Mast Kalandar', 'Crunch Pizzas', 'Lazeez', 'US Pizza', 'Wangs Kitchen', 'Wangs Kitchen', 'Zaika Take Away', 'Pizza Hut', 'Subway', 'American Bites', 'Mast Kalandar', 'Mast Kalandar', 'Imperia Restaurant', 'New Tandoori Point', 'Night Spoon', 'Punjabi Daawat', "Nakkala's Food Hunt", 'Mast Kalandar', 'New Tandoori Point', 'Raenss Cafe', 'Mast Kalandar', 'Raenss Cafe', 'Mast Kalandar', 'Imperia Restaurant', 'Punjabi Daawat', 'Crunch Pizzas', 'Raenss Cafe', 'Wangs Kitchen', 'American Bites', "Domino's Pizza", 'Wangs Kitchen', 'American Bites', 'Raenss Cafe', 'Mast Kalandar', 'Paratha Junction', 'Punjabi Daawat', 'Punjabi Daawat', 'Mast Kalandar', 'New Tandoori Point', 'US Pizza', 'Zaika Take Away', 'New Tandoori Point', 'Raenss Cafe', 'Punjabi Daawat', 'Paratha Junction', "Nakkala's Food Hunt", 'American Bites', 'Wangs Kitchen', 'Raenss Cafe', 'Mast Kalandar', "Woody's", 'Crunch Pizzas', "Navya's", "Ammi's Biryani", 'Grills & Rolls', 'Spotlight - The Golden Tulip', 'Wangs Kitchen', 'Wangs Kitchen', 'Mast Kalandar', 'HungerLoft', 'Wangs Kitchen', 'The Chaat Shop', 'HungerLoft', 'Hotel Hyperdine', 'Swaadishta Restaurant', 'The Chaat Shop', 'Wangs Kitchen', 'Shaadi Ki Biryani', "Woody's", 'Hotel Hyperdine', 'Mast Kalandar', 'Food Theory', 'Grills & Rolls', 'Gundappa Donne Biryani', 'Bhagini', 'Crunch Pizzas', "Vasudev Adiga's", 'The Chaat Shop', 'Dal Tadkaa', 'Java City', 'Chung Wah', "Woody's", 'Mast Kalandar', 'HungerLoft', 'Gold Bean', 'Mast Kalandar', 'Wangs Kitchen', 'Crunch Pizzas', 'Dal Tadkaa', 'A2B - Adyar Ananda Bhavan', 'The Chaat Shop', 'Imperia Restaurant', 'Shaadi Ki Biryani', 'Spotlight - The Golden Tulip', 'Mast Kalandar', "Woody's", 'Wangs Kitchen', 'Grills & Rolls', "Woody's", 'Java City', 'Grills & Rolls', 'Java City', 'HungerLoft', 'HungerLoft', 'Wangs Kitchen', 'Mayuri', 'HungerLoft', 'Halli Kitchen', 'Swaadishta Restaurant', 'The Chaat Shop', 'Wangs Kitchen', 'Halli Kitchen', 'Crunc ...

# %%
df = pd.DataFrame(FoodieBay)

# Count the number of restaurants in each city
city_counts = df['location'].value_counts()

# Find the city with the greatest number of restaurants
greatest_city = city_counts.idxmax()
max_restaurants = city_counts.max()
print(greatest_city)
print(max_restaurants)
# Out:
# BTM
# 4422

# %% [markdown]
# ###**Multivariate Analysis**

# %%
# Identify columns with non-numeric data
non_numeric_cols = FoodieBay.select_dtypes(exclude=['number']).columns

# Drop non-numeric columns before calculating correlations
numeric_FoodieBay = FoodieBay.drop(non_numeric_cols, axis=1)

# Generate the heatmap
sns.heatmap(data=numeric_FoodieBay.corr(), cmap='Blues', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##**Treating missing data**

# %%
print(FoodieBay.isnull().sum().sort_values(ascending=0))
# Out:
# dish_liked            22779
# rate                   8336
# ave_review_ranking     6379
# phone                   884
# ave_cost_for_two        240
# cuisines                 18
# online_order              0
# votes                     0
# book_table                0
# url                       0
# listed_in_city            0
# address                   0
# menu_item                 0
# rest_type                 0
# location                  0
# name                      0
# listed_in_type            0
# dtype: int64

# %%
sns.histplot(data= FoodieBay, x='ave_review_ranking', bins= 15)
# Out:
# <Axes: xlabel='ave_review_ranking', ylabel='Count'>

# %%
sns.boxplot(data=FoodieBay, x='ave_review_ranking', showmeans=True)
# Out:
# <Axes: xlabel='ave_review_ranking'>

# %%
sns.histplot(data= FoodieBay, x='ave_cost_for_two', bins= 15)
# Out:
# <Axes: xlabel='ave_cost_for_two', ylabel='Count'>

# %%
sns.boxplot(data=FoodieBay, x='ave_cost_for_two', showmeans=True)
# Out:
# <Axes: xlabel='ave_cost_for_two'>

# %%
#Drop all rows with missing values in target column
FoodieBay.dropna(subset=['rate'], inplace=True)

# %%
#Fill in missing numerical data with median
FoodieBay['ave_review_ranking'].fillna(FoodieBay['ave_review_ranking'].median(), inplace=True)
FoodieBay['ave_cost_for_two'].fillna(FoodieBay['ave_cost_for_two'].median(), inplace=True)

# %%
print(FoodieBay.isnull().sum().sort_values(ascending=0))
# Out:
# dish_liked            14551
# phone                   634
# cuisines                  8
# url                       0
# online_order              0
# ave_review_ranking        0
# votes                     0
# ave_cost_for_two          0
# book_table                0
# listed_in_type            0
# listed_in_city            0
# address                   0
# menu_item                 0
# rest_type                 0
# location                  0
# name                      0
# rate                      0
# dtype: int64

# %% [markdown]
# ## **Supervised Machine Learning Model**

# %%
#selecting relevant features and train and evaluate a model
features_1=['online_order', 'book_table','ave_cost_for_two', 'ave_review_ranking','votes']
X=FoodieBay[features_1]
X.head()
# Out:
#    online_order  book_table  ave_cost_for_two  ave_review_ranking  votes
# 0             0           0               700                   5     13
# 1             1           0               400                   4     28
# 2             1           0               200                   4     18
# 3             1           1              1200                   5    550
# 4             1           0               250                   3     67

# %%
#specifying the label
y=FoodieBay['rate']
y.head()
# Out:
# 0   4
# 1   4
# 2   4
# 3   4
# 4   4
# Name: rate, dtype: float64

# %%
print(FoodieBay.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31794 entries, 0 to 40129
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   url                 31794 non-null  object
#  1   address             31794 non-null  object
#  2   name                31794 non-null  object
#  3   phone               31160 non-null  object
#  4   location            31794 non-null  object
#  5   rest_type           31794 non-null  int64
#  6   cuisines            31786 non-null  object
#  7   menu_item           31794 non-null  object
#  8   listed_in_type      31794 non-null  int64
#  9   listed_in_city      31794 non-null  object
#  10  online_order        31794 non-null  int64
#  11  book_table          31794 non-null  int64
#  12  ave_cost_for_two    31794 non-null  float64
#  13  dish_liked          17243 non-null  object
#  14  votes               31794 non-null  int64
#  15  ave_review_ranking  31794 non-null  float64
#  16  rate                31794 non-null  float64
# dtypes: float64(3), int64(5), object(9)
# memory usage: 4.4+ MB
# None

# %% [markdown]
# ## **Split the dataset**

# %%
# Split dataset into training set 80% and test set 20%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2023)

#inspect the split datasets
print(X_train.head())
print(y_train.head())

print('Training dataset size:',X_train.shape)
print('Test dataset size:',X_test.shape)
# Out:
#        online_order  book_table  ave_cost_for_two  ave_review_ranking  votes
# 31057             1           0               300                   4     12
# 24957             1           0               250                   1      8
# 12362             1           0               150                   2      7
# 9844              1           0               300                   3     39
# 15403             0           0               300                   3     17
# 31057   3
# 24957   3
# 12362   3
# 9844    4
# 15403   4
# Name: rate, dtype: float64
# Training dataset size: (25435, 5)
# Test dataset size: (6359, 5)

# %% [markdown]
# ###**Linear Regression Model**

# %% [markdown]
# #### **Train a linear model**

# %%
#create a linear_model object

#import linear_model
from sklearn import linear_model


reg = linear_model.LinearRegression()

# %%
# Train a Regression model (regressor) with the training dataset
reg=reg.fit(X_train, y_train)

# %% [markdown]
# #### **Make predictions**
# Make predictions using the model and the test set

# %%
#Make predictions for the test dataset
y_pred = reg.predict(X_test)

# %% [markdown]
# **Inspect the predictions and the original labels**

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual prices")
plt.ylabel("Predicted prices")
plt.title("Actual prices vs Predicted prices")
plt.show()

# %%
#set the formatting for floating numbers
pd.set_option('display.float_format', lambda x: '%.0f' % x)
area=X_test[features_1]
#inspection
inspection=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})

inspection.head(20)
# Out:
#        Actual  Predicted
# 15646       3          3
# 19014       4          4
# 24330       3          4
# 2873        4          4
# 16518       4          4
# 14396       4          4
# 9936        4          4
# 32874       4          4
# 31844       4          5
# 24289       3          4
# 7355        4          4
# 37675       4          4
# 4036        4          4
# 33186       4          4
# 20196       3          4
# 27518       3          3
# 28344       4          4
# 24032       4          4
# 36762       4          4
# 22510       4          4

# %% [markdown]
# #### **Performance evaluation**

# %%
# Import necessary libraries
from sklearn.metrics import mean_squared_error, r2_score

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
r2 = r2_score(y_test, y_pred)              # R-squared

# Print the evaluation metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 0.10485616737792637
# R-squared (R2): 0.4381257569395912

# %%
from sklearn.metrics import mean_squared_error

# Calculate and print the root mean square error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Square Error: {rmse}")
# Out:
# Root Mean Square Error: 0.32381502030932163

# %%
#Examine the performance using the descriptive stats of price
inspection['Actual'].describe()
# Out:
# count   6359
# mean       4
# std        0
# min        2
# 25%        3
# 50%        4
# 75%        4
# max        5
# Name: Actual, dtype: float64

# %%
#Examine the performance using the descriptive stats of predicted price
inspection['Predicted'].describe()
# Out:
# count   6359
# mean       4
# std        0
# min        3
# 25%        3
# 50%        4
# 75%        4
# max        6
# Name: Predicted, dtype: float64

# %% [markdown]
# ### **Decision Tree Regressor Model**

# %%
#Import DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(max_depth=20, max_leaf_nodes=15, random_state=1)

regressor
# Out:
# DecisionTreeRegressor(max_depth=20, max_leaf_nodes=15, random_state=1)

# %%
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, max_leaf_nodes=15, random_state=1)

# %%
#predict prices
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### **Evaluate the model performance**

# %%
#Evaluate the model
from sklearn import metrics
print('Mean Absolute Error:', '%.3f' % metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', '%.3f' % metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', '%.3f' %np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.204
# Mean Squared Error: 0.081
# Root Mean Squared Error: 0.285

# %%
print("R-squared: %.3f" % metrics.r2_score(y_test, y_pred))
# Out:
# R-squared: 0.565

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)
inspection['Actual'].describe()
# Out:
# count   6359
# mean       4
# std        0
# min        2
# 25%        3
# 50%        4
# 75%        4
# max        5
# Name: Actual, dtype: float64

# %%
inspection['Predicted'].describe()
# Out:
# count   6359
# mean       4
# std        0
# min        3
# 25%        3
# 50%        4
# 75%        4
# max        6
# Name: Predicted, dtype: float64

# %% [markdown]
# #### **Visualise the trees**

# %%
#Import plot_tree to  extract rules and visualise the decition tree model
from sklearn.tree import plot_tree, export_text
from pandas.io.parsers.readers import annotations

# %%
# Convert feature_names to a list if it's an Index object
feature_names = list(features_1) if isinstance(features_1, pd.Index) else features_1

# Extract the decision rules
rules = export_text(regressor, feature_names=feature_names)
print(rules)
# Out:
# |--- votes <= 137.50
# |   |--- ave_review_ranking <= 3.29
# |   |   |--- ave_review_ranking <= 2.91
# |   |   |   |--- online_order <= 0.50
# |   |   |   |   |--- value: [3.06]
# |   |   |   |--- online_order >  0.50
# |   |   |   |   |--- value: [3.23]
# |   |   |--- ave_review_ranking >  2.91
# |   |   |   |--- value: [3.39]
# |   |--- ave_review_ranking >  3.29
# |   |   |--- votes <= 17.50
# |   |   |   |--- votes <= 8.50
# |   |   |   |   |--- value: [3.34]
# |   |   |   |--- votes >  8.50
# |   |   |   |   |--- value: [3.49]
# |   |   |--- votes >  17.50
# |   |   |   |--- ave_review_ranking <= 3.56
# |   |   |   |   |--- value: [3.58]
# |   |   |   |--- ave_review_ranking >  3.56
# |   |   |   |   |--- votes <= 48.50
# |   |   |   |   |   |--- value: [3.69]
# |   |   |   |   |--- votes >  48.50
# |   |   |   |   |   |--- value: [3.85]
# |--- votes >  137.50
# |   |--- ave_review_ranking <= 3.26
# |   |   |--- ave_review_ranking <= 2.66
# |   |   |   |--- online_order <= 0.50
# |   |   |   |   |--- value: [2.77]
# |   |   |   |--- online_order >  0.50
# |   |   |   |   |--- value: [3.38]
# |   |   |--- ave_review_ranking >  2.66
# |   |   |   |--- value: [3.63]
# |   |--- ave_review_ranking >  3.26
# |   |   |--- ave_review_ranking <= 4.00
# |   |   |   |--- votes <= 446.50
# |   |   |   |   |--- value: [3.87]
# |   |   |   |--- votes >  446.50
# |   |   |   |   |--- value: [4.08]
# |   |   |--- ave_review_ranking >  4.00
# |   |   |   |--- ave_cost_for_two <= 875.00
# |   |   |   |   |--- value: [4.12]
# |   |   |   |--- ave_cost_for_two >  875.00
# |   |   |   |   |--- value: [4.38]

# %%
# visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(regressor, filled=True, feature_names=features_1, class_names=['0','1'])
plt.show()

# %% [markdown]
# #**Unsupervised Learning**

# %%
# Selecting relevant features for clustering
features_2=['online_order', 'book_table','ave_cost_for_two', 'ave_review_ranking','votes']

X = FoodieBay[features_2]

# %%
X.describe()
# Out:
#        online_order  book_table  ave_cost_for_two  ave_review_ranking  votes
# count         31794       31794             31794               31794  31794
# mean              1           0               547                   4    284
# std               0           0               339                   1    660
# min               0           0                40                   1      0
# 25%               0           0               300                   3     20
# 50%               1           0               500                   4     68
# 75%               1           0               700                   4    244
# max               1           1              2500                   5  12121

# %%
#import scaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Scale the features using Min-Max Scaling
scaler = MinMaxScaler()

# %%
# Features to scale
features_to_scale = ['online_order', 'book_table','ave_cost_for_two', 'ave_review_ranking','votes' ]

# Fit and transform the features to scale on the training data
X_scaled_values = scaler.fit_transform(X)

# Create DataFrames from the scaled values
X_features_scaled = pd.DataFrame(X_scaled_values, columns=features_to_scale)
X_scaled = X_features_scaled

# %%
X_scaled.describe()
# Out:
#        online_order  book_table  ave_cost_for_two  ave_review_ranking  votes
# count         31794       31794             31794               31794  31794
# mean              1           0                 0                   1      0
# std               0           0                 0                   0      0
# min               0           0                 0                   0      0
# 25%               0           0                 0                   0      0
# 50%               1           0                 0                   1      0
# 75%               1           0                 0                   1      0
# max               1           1                 1                   1      1

# %% [markdown]
# ---

# %% [markdown]
# ## **K-Means clustering**

# %% [markdown]
# ### **Model building**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Fit K-means clustering model with a 'guessed' number of clusters
k=5
kmeans = KMeans(n_clusters=k, n_init='auto',max_iter=300, random_state=2023)

#fit kmeans with X_scaled
kmeans.fit(X_scaled)

# Add cluster labels to original dataset
FoodieBay['Cluster'] = kmeans.labels_

# %% [markdown]
# ## **Clustering Evaluation**

# %% [markdown]
# ###**Within-Cluster Sum of Squares**

# %%
# Evaluate the model using within-cluster sum of squares (WCSS)
wcss = kmeans.inertia_
print("Within-Cluster Sum of Squares (WCSS):", '%.3f' % wcss)
# Out:
# Within-Cluster Sum of Squares (WCSS): 1250.001

# %% [markdown]
# ### **The Davies-Bouldin Index (DBI)**

# %%
from sklearn.metrics import davies_bouldin_score

# Compute the Davies-Bouldin index
dbs = davies_bouldin_score(X_scaled, kmeans.labels_)
print("Davies Bouldin index:", '%.3f' % dbs)
# Out:
# Davies Bouldin index: 0.561

# %% [markdown]
# ### **Silhouette score**

# %%
# Compute the Silhouette score for the clustering model
silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)

print('Silhouette score:', '%.3f' % silhouette_avg)
# Out:
# Silhouette score: 0.566

# %%
#Import funtions to visualise silhouette score
from sklearn.metrics import silhouette_samples, silhouette_score
from matplotlib.ticker import FixedLocator, FixedFormatter
import matplotlib.cm as cm

# %%
#fit kmeans with X_scaled to get labels
cluster_labels = kmeans.fit_predict(X_scaled)

# %%
# Compute silhouette scores
silhouette_avg = silhouette_score(X_scaled, cluster_labels)
sample_silhouette_values = silhouette_samples(X_scaled, cluster_labels)

# Plot silhouette diagram
n_clusters = 5
fig, ax = plt.subplots()
y_lower, y_upper = 0, 0

# Define the colormap, options include: autumn, Spectral, viridis, plasma, cool, jet
cmap = cm.Spectral

# Create a list of evenly spaced values in the range [0, 1]
values = np.linspace(0, 1, n_clusters)

for i in range(n_clusters):
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
    ith_cluster_silhouette_values.sort()
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper += size_cluster_i
    color = cmap(values[i])
    ax.barh(range(y_lower, y_upper), ith_cluster_silhouette_values, height=1.0,
            edgecolor='none', color=color)
    ax.text(-0.1, (y_lower + y_upper) / 2, 'Cluster ' + str(i), color='black', fontsize=10)
    y_lower += size_cluster_i

ax.axvline(x=silhouette_avg, color="red", linestyle="--")
ax.set_xlabel("Silhouette coefficient values")
ax.set_ylabel("Cluster labels")
ax.set_yticks([])
ax.set_xlim([-0.1, 1])
ax.set_ylim([0, len(X_scaled) + (n_clusters + 1) * 10])

plt.show()

# %% [markdown]
# ## **Optimising k**

# %% [markdown]
# ### **Use the elbow method based on the SSE (WCSS) score**

# %%
# Determine optimal number of clusters using the SSE metric
sse_scores = []
best_k=2
best_sse_score=4622.613
for i in range(2, 41):
  kmeans = KMeans(n_clusters=i, n_init=2)
  kmeans.fit(X_scaled)
  sse_score_i=kmeans.inertia_
  sse_scores.append(sse_score_i)
  if best_sse_score > sse_score_i:
    best_k = i
    best_sse_score = sse_score_i

print('Best k: ', best_k)
print('Best within cluster sum of squarred error score: ', '%.3f' %best_sse_score)
# Out:
# Best k:  40
# Best within cluster sum of squarred error score:  197.303

# %%
# Plot the silhouette scores to determine optimal number of clusters
plt.plot(range(2,41), sse_scores)
plt.xlabel("Number of clusters")
plt.ylabel("Within cluster sum of squarred error score")
plt.show()

# %% [markdown]
# ### **Optimise the number of clusters based on the silhouette score**

# %%
sil_scores = []
best_k = 2
best_sil_score = -1  # Initialize with a negative value

for i in range(2, 41):
    kmeans = KMeans(n_clusters=i, n_init=2, random_state=2023)
    kmeans.fit(X_scaled)
    sil_score_i = silhouette_score(X_scaled, kmeans.labels_)
    sil_scores.append(sil_score_i)
    if best_sil_score < sil_score_i:
        best_k = i
        best_sil_score = sil_score_i

print('Best k:', best_k)
print('Best silhouette score: %.3f' % best_sil_score)
# Out:
# Best k: 4
# Best silhouette score: 0.729

# %%
# Plot the silhouette scores to determine optimal number of clusters
plt.plot(range(2,41), sil_scores)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.show()

# %% [markdown]
# **Let's create a graph to observe both metrics**

# %%
# Create a figure and a set of subplots (two y-axes)
fig, ax1 = plt.subplots()

cluster_range = range(2, 41)

# Plot SSE
color = 'tab:red'
ax1.set_xlabel('Number of Clusters')
ax1.set_ylabel('SSE', color=color)
ax1.plot(cluster_range, sse_scores, marker='o', label='SSE', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create the second y-axis to plot Silhouette Score
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Silhouette Score', color=color)
ax2.plot(cluster_range, sil_scores, marker='x', linestyle='--', label='Silhouette Score', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Show legend
ax1.legend(loc='upper left', bbox_to_anchor=(0.0, 1.0))
ax2.legend(loc='upper left', bbox_to_anchor=(0.0, 0.9))

# Show plot
plt.title("SSE and Silhouette Score for Different Number of Clusters")
plt.show()

# %% [markdown]
# ## **Model Selection**

# %%
# let's go with k=4
n_clusters= 4

# %%
# initialise the model object
kmeans = KMeans(n_clusters=best_k,n_init='auto', random_state=2023)

#Fit K-means clustering model with the selected number of clusters
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=4, n_init='auto', random_state=2023)

# %%
# Add cluster labels to original dataset
FoodieBay['Cluster'] = kmeans.labels_

# %%
# Evaluate the model using within-cluster sum of squares (WCSS)
wcss = kmeans.inertia_
print("Within-Cluster Sum of Squares (WCSS):", '%.3f' % wcss)

# Compute the Davies-Bouldin index
dbs = davies_bouldin_score(X_scaled, kmeans.labels_)
print("Davies Bouldin index:", '%.3f' % dbs)

# Compute the Silhouette score for the clustering model
silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)

print('Silhouette score:', '%.3f' % silhouette_avg)
# Out:
# Within-Cluster Sum of Squares (WCSS): 1838.361
# Davies Bouldin index: 0.405
# Silhouette score: 0.729

# %% [markdown]
# **Let's create the silhouette plot**

# %%
# Compute sample silhouette scores
cluster_labels = kmeans.labels_
sample_silhouette_values = silhouette_samples(X_scaled, cluster_labels)

# Create a color map
cmap = cm.get_cmap("Spectral")

# Create a list of evenly spaced values in the range [0, 1]
values = np.linspace(0, 1, n_clusters)

# Plot silhouette diagram
fig, ax = plt.subplots()
y_lower, y_upper = 0, 0
for i in range(n_clusters):
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
    ith_cluster_silhouette_values.sort()
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper += size_cluster_i
    color = cmap(values[i])
    ax.barh(range(y_lower, y_upper), ith_cluster_silhouette_values, height=1.0,
            edgecolor='none', color=color)
    ax.text(-0.1, (y_lower + y_upper) / 2, 'Cluster ' + str(i), color='black', fontsize=10)
    y_lower += size_cluster_i

ax.axvline(x=silhouette_avg, color="red", linestyle="--")
ax.set_xlabel("Silhouette coefficient values")
ax.set_ylabel("Cluster labels")
ax.set_yticks([])
ax.set_xlim([-0.1, 1])
ax.set_ylim([0, len(X_scaled) + (n_clusters + 1) * 10])

ax.text(silhouette_avg + 0.05, len(X_scaled) + 5, "Number of clusters = %d" % n_clusters, fontsize=10, fontweight='bold')

plt.show()
# Out:
# <ipython-input-232-91266c7e9823>:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("Spectral")

# %% [markdown]
# ## **Post-analysis for Cluster Profiling**

# %%
FoodieBay[['online_order', 'book_table','ave_cost_for_two', 'ave_review_ranking','votes']]
# Out:
#        online_order  book_table  ave_cost_for_two  ave_review_ranking  votes
# 0                 0           0               700                   5     13
# 1                 1           0               400                   4     28
# 2                 1           0               200                   4     18
# 3                 1           1              1200                   5    550
# 4                 1           0               250                   3     67
# ...             ...         ...               ...                 ...    ...
# 40125             0           0               500                   2     25
# 40126             1           0               500                   3     23
# 40127             0           0               300                   3     23
# 40128             1           0               500                   4    162
# 40129             1           0               350                   3    163
#
# [31794 rows x 5 columns]

# %%
cluster_count=FoodieBay.Cluster.value_counts()
cluster_count
# Out:
# Cluster
# 2    19064
# 1     8730
# 0     2871
# 3     1129
# Name: count, dtype: int64

# %%
#Let's generate a pie chart with the distribution of churned cases, along with percentage labels.

# Sort the index to ensure the clusters are in order
sorted_cluster_count = cluster_count.sort_index()

colours = sns.color_palette("tab10", n_colors=len(cluster_count))

plt.pie(cluster_count, labels=sorted_cluster_count.index, autopct='%1.1f%%', colors= colours)
plt.title('Distribution of Clusters')
plt.show()

# %%
FoodieBay.groupby('Cluster')['online_order'].describe()
# Out:
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871     1    0    1    1    1    1    1
# 1         8730     0    0    0    0    0    0    0
# 2        19064     1    0    1    1    1    1    1
# 3         1129     0    0    0    0    0    0    0

# %%
FoodieBay.groupby('Cluster')['ave_review_ranking'].describe()
# Out:
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871     4    1    1    4    4    4    5
# 1         8730     4    1    1    3    4    4    5
# 2        19064     4    1    1    3    4    4    5
# 3         1129     4    1    1    4    4    4    5

# %%
FoodieBay.groupby('Cluster')['ave_cost_for_two'].describe()
# Out:
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871  1040  364  300  800 1000 1300 2500
# 1         8730   467  281   50  300  400  600 2200
# 2        19064   468  226   40  300  400  600 2000
# 3         1129  1231  430  300  900 1100 1500 2500

# %%
FoodieBay.groupby('Cluster')['book_table'].describe()
# Out:
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871     1    0    1    1    1    1    1
# 1         8730     0    0    0    0    0    0    0
# 2        19064     0    0    0    0    0    0    0
# 3         1129     1    0    1    1    1    1    1

# %%
FoodieBay.groupby('Cluster')['votes'].describe()
# Out:
#          count  mean  std  min  25%  50%  75%   max
# Cluster
# 0         2871   943  936    0  258  612 1368  6470
# 1         8730   140  447    0    9   25   77  7137
# 2        19064   205  460    0   24   73  211  8304
# 3         1129  1068 1706    8  174  455 1212 12121

# %%
# Get centroids of the clusters
centroids = kmeans.cluster_centers_

# Display the centroids
for idx, centroid in enumerate(centroids):
    print(f"Cluster {idx} centroid values:")
    for feature, value in zip(features_1, centroid):
        print(f"  {feature}: {value:.2f}")
    print("\n")

# To identify importance, you can look at the difference between centroids
for idx, feature in enumerate(features_1):
    print(f"Range for {feature}: {max(centroid[idx] for centroid in centroids) - min(centroid[idx] for centroid in centroids):.2f}")
# Out:
# Cluster 0 centroid values:
#   online_order: 1.00
#   book_table: 1.00
#   ave_cost_for_two: 0.41
#   ave_review_ranking: 0.71
#   votes: 0.08
#
#
# Cluster 1 centroid values:
#   online_order: 0.00
#   book_table: -0.00
#   ave_cost_for_two: 0.17
#   ave_review_ranking: 0.66
#   votes: 0.01
#
#
# Cluster 2 centroid values:
#   online_order: 1.00
#   book_table: -0.00
#   ave_cost_for_two: 0.17
#   ave_review_ranking: 0.63
#   votes: 0.02
#
#
# Cluster 3 centroid values:
#   online_order: -0.00
#   book_table: 1.00
#   ave_cost_for_two: 0.48
#   ave_review_ranking: 0.73
#   votes: 0.09
#
#
# Range for online_order: 1.00
# Range for book_table: 1.00
# Range for ave_cost_for_two: 0.31
# Range for ave_review_ranking: 0.10
# Range for votes: 0.08

# %%
from mpl_toolkits.mplot3d import Axes3D

# Create a new figure
fig = plt.figure(figsize=(12, 8))

# Add 3D subplot
# The '111' means 1x1 grid, first subplot, similar to MATLAB-style
ax = fig.add_subplot(111, projection='3d')

# Unique cluster labels
unique_clusters = FoodieBay['Cluster'].unique()

# Color map
colors = plt.cm.jet(np.linspace(0, 1, len(unique_clusters)))

# Adjusting the viewing angle for better visibility
ax.view_init(elev=20, azim=-70)  # Modify these values as needed

# Scatter plot for each cluster
for i, cluster in enumerate(unique_clusters):
    cluster_data = FoodieBay[FoodieBay['Cluster'] == cluster]
    ax.scatter(cluster_data['ave_cost_for_two'], cluster_data['ave_review_ranking'],cluster_data['rate'],
               label=f'Cluster {cluster}', c=[colors[i]])

# Legend and labels
ax.set_xlabel('MonthlyCharges')
ax.set_ylabel('Tenure')
ax.set_zlabel('Churn')
ax.legend()

# Show the plot
plt.show()

# %%
nums = ['ave_cost_for_two', 'ave_review_ranking', 'votes']

# Create subplots outside the loop
fig, axes = plt.subplots(len(nums), 1, figsize=(14, 6 * len(nums)))

for idx, i in enumerate(nums):
    print(i, ':\n')
    print(FoodieBay.groupby('Cluster')[i].describe())
    print('\n')

    # Plot KDE on the current subplot
    sns.kdeplot(data=FoodieBay, x=i, hue='Cluster', palette='tab10', ax=axes[idx])
    axes[idx].set_title(f'{i} KDE plot')

# Show all subplots after the loop
plt.show()
# Out:
# ave_cost_for_two :
#
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871  1040  364  300  800 1000 1300 2500
# 1         8730   467  281   50  300  400  600 2200
# 2        19064   468  226   40  300  400  600 2000
# 3         1129  1231  430  300  900 1100 1500 2500
#
#
# ave_review_ranking :
#
#          count  mean  std  min  25%  50%  75%  max
# Cluster
# 0         2871     4    1    1    4    4    4    5
# 1         8730     4    1    1    3    4    4    5
# 2        19064     4    1    1    3    4    4    5
# 3         1129     4    1    1    4    4    4    5
#
#
# votes :
#
#          count  mean  std  min  25%  50%  75%   max
# Cluster
# 0         2871   943  936    0  258  612 1368  6470
# 1         8730   140  447    0    9   25   77  7137
# 2        19064   205  460    0   24   73  211  8304
# 3         1129  1068 1706    8  174  455 1212 12121

# %%
sns.clustermap(data=FoodieBay[['online_order', 'book_table','ave_cost_for_two', 'ave_review_ranking','votes','rate']].corr(), cmap="Blues", linewidths=.9, annot=True)
